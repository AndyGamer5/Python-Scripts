# %% [markdown]
# # Construir el siguiente DataFrame

# %%
import pandas as pd

datos = {
" Producto ":
[" Mouse "," Teclado ",
" Monitor "," Laptop "] ,
" Precio ":
[250 ,450 ,3200 ,15000] ,
" Existencia ":
[20 ,15 ,8 ,5]
}

df = pd.DataFrame(datos)
# Out:
# Running cells with 'Python 3.14.3' requires the ipykernel package.
#
# <a href='command:jupyter.createPythonEnvAndSelectController'>Create a Python Environment</a> with the required packages.
#
# Or install 'ipykernel' using the command: 'c:/Users/andre/.local/bin/python3.14.exe -m pip install ipykernel -U --user --force-reinstall'

# %%
" Producto ":
[" Mouse "," Teclado ",
" Monitor "," Laptop "] ,
" Precio ":
[250 ,450 ,3200 ,15000] ,
" Existencia ":
[20 ,15 ,8 ,5]
}

df = pd.DataFrame(datos)

# %% [markdown]
# # Columna precio

# %%
df["precio"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df["precio"]
#
# NameError: name 'df' is not defined
